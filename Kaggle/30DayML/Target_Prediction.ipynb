# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Load Data

# %%
tr = pd.read_csv('train.csv')
ts = pd.read_csv('test.csv')

# %%
tr.shape
# Out:
# (300000, 26)

# %%
tr.head()
# Out:
#    id cat0 cat1 cat2 cat3 cat4 cat5 cat6 cat7 cat8  ...     cont5     cont6  \
# 0   1    B    B    B    C    B    B    A    E    C  ...  0.400361  0.160266
# 1   2    B    B    A    A    B    D    A    F    A  ...  0.533087  0.558922
# 2   3    A    A    A    C    B    D    A    D    A  ...  0.650609  0.375348
# 3   4    B    B    A    C    B    D    A    E    C  ...  0.668980  0.239061
# 4   6    A    A    A    C    B    D    A    E    A  ...  0.686964  0.420667
#
#       cont7     cont8     cont9    cont10    cont11    cont12    cont13  \
# 0  0.310921  0.389470  0.267559  0.237281  0.377873  0.322401  0.869850
# 1  0.516294  0.594928  0.341439  0.906013  0.921701  0.261975  0.465083
# 2  0.902567  0.555205  0.843531  0.748809  0.620126  0.541474  0.763846
# 3  0.732948  0.679618  0.574844  0.346010  0.714610  0.540150  0.280682
# 4  0.648182  0.684501  0.956692  1.000773  0.776742  0.625849  0.250823
#
#      target
# 0  8.113634
# 1  8.481233
# 2  8.364351
# 3  8.049253
# 4  7.972260
#
# [5 rows x 26 columns]

# %%
tr.describe()
# Out:
#                   id          cont0          cont1          cont2  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean   250018.576947       0.527335       0.460926       0.490498
# std    144450.150010       0.230599       0.214003       0.253346
# min         1.000000      -0.118039      -0.069309      -0.056104
# 25%    124772.500000       0.405965       0.310494       0.300604
# 50%    250002.500000       0.497053       0.427903       0.502462
# 75%    375226.500000       0.668060       0.615113       0.647512
# max    499999.000000       1.058443       0.887253       1.034704
#
#                cont3          cont4          cont5          cont6  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.496689       0.491654       0.510526       0.467476
# std         0.219199       0.240074       0.228232       0.210331
# min         0.130676       0.255908       0.045915      -0.224689
# 25%         0.329783       0.284188       0.354141       0.342873
# 50%         0.465026       0.390470       0.488865       0.429383
# 75%         0.664451       0.696599       0.669625       0.573383
# max         1.039560       1.055424       1.067649       1.111552
#
#                cont7          cont8          cont9         cont10  \
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.537119       0.498456       0.474872       0.474492
# std         0.218140       0.239920       0.218007       0.255949
# min         0.203763      -0.260275       0.117896       0.048732
# 25%         0.355825       0.332486       0.306874       0.276017
# 50%         0.504661       0.439151       0.434620       0.459975
# 75%         0.703441       0.606056       0.614333       0.691579
# max         1.032837       1.040229       0.982922       1.055960
#
#               cont11         cont12         cont13         target
# count  300000.000000  300000.000000  300000.000000  300000.000000
# mean        0.473216       0.494561       0.508273       8.241979
# std         0.222022       0.247292       0.222950       0.746555
# min         0.052608      -0.074208       0.151050       0.140329
# 25%         0.308151       0.289074       0.300669       7.742071
# 50%         0.433812       0.422887       0.472400       8.191373
# 75%         0.642057       0.714502       0.758447       8.728634
# max         1.071444       0.975035       0.905992      10.411992

# %%
tr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 26 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   id      300000 non-null  int64
#  1   cat0    300000 non-null  object
#  2   cat1    300000 non-null  object
#  3   cat2    300000 non-null  object
#  4   cat3    300000 non-null  object
#  5   cat4    300000 non-null  object
#  6   cat5    300000 non-null  object
#  7   cat6    300000 non-null  object
#  8   cat7    300000 non-null  object
#  9   cat8    300000 non-null  object
#  10  cat9    300000 non-null  object
#  11  cont0   300000 non-null  float64
#  12  cont1   300000 non-null  float64
#  13  cont2   300000 non-null  float64
#  14  cont3   300000 non-null  float64
#  15  cont4   300000 non-null  float64
#  16  cont5   300000 non-null  float64
#  17  cont6   300000 non-null  float64
#  18  cont7   300000 non-null  float64
#  19  cont8   300000 non-null  float64
#  20  cont9   300000 non-null  float64
#  21  cont10  300000 non-null  float64
#  22  cont11  300000 non-null  float64
#  23  cont12  300000 non-null  float64
#  24  cont13  300000 non-null  float64
#  25  target  300000 non-null  float64
# dtypes: float64(15), int64(1), object(10)
# memory usage: 59.5+ MB

# %% [markdown]
# ## Preprocess Data

# %%
## Drop id Column
train = tr.drop('id', axis = 'columns')
test = ts.drop('id', axis = 'columns')
print('Train Data shape before dropping "id" Column {} \nTrain Data shape after dropping "id" Column {}'.format(tr.shape,train.shape))
print('\nTest Data shape before dropping "id" Column {} \nTest Data shape after dropping "id" Column {}'.format(ts.shape,test.shape))

## Separate Features and Target
y = tr['target']
features = train.drop('target', axis = 'columns')
print('\nTarget Shape {} \nFeatures Data shape {}'.format(y.shape,features.shape))
# Out:
# Train Data shape before dropping "id" Column (300000, 26)
# Train Data shape after dropping "id" Column (300000, 25)
#
# Test Data shape before dropping "id" Column (200000, 25)
# Test Data shape after dropping "id" Column (200000, 24)
#
# Target Shape (300000,)
# Features Data shape (300000, 24)

# %%
categorical_cols = [col for col in features.columns if features[col].dtype == 'O']
num_cols = [col for col in features.columns if features[col].dtype in ('int64', 'float64')]

# %%
i = 0
for col in categorical_cols:
    print('Number of Categories in {} column are {}'.format(col, len(features[col].unique())))
    i += len(features[col].unique())
print('Total Unique entries in Categorical columns {}'.format(i))
# Out:
# Number of Categories in cat0 column are 2
# Number of Categories in cat1 column are 2
# Number of Categories in cat2 column are 2
# Number of Categories in cat3 column are 4
# Number of Categories in cat4 column are 4
# Number of Categories in cat5 column are 4
# Number of Categories in cat6 column are 8
# Number of Categories in cat7 column are 8
# Number of Categories in cat8 column are 7
# Number of Categories in cat9 column are 15
# Total Unique entries in Categorical columns 56

# %%
# categorical_cols = categorical_cols[0:-1]
# high_cardinality_cols = ['cat9']
# print('Categorical Columns {}\nHigh Cardinality Categorical Columns {}\nNumerical Columns {}'.format(len(categorical_cols),
#                                                                                                     len(high_cardinality_cols),
#                                                                                                     len(num_cols)))

# %% [markdown]
# ## Split Train and Validation Data

# %%
## Train test split
y = tr['target']
X = features.copy()
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print('X_train {}'.format(X_train.shape))
print('X_valid {}'.format(X_valid.shape))
print('y_train {}'.format(y_train.shape))
print('y_valid {}'.format(y_valid.shape))
# Out:
# X_train (240000, 24)
# X_valid (60000, 24)
# y_train (240000,)
# y_valid (60000,)

# %% [markdown]
# ## OnehotEncode all traindata

# %%
X1 = pd.get_dummies(X, drop_first=True)
print(X1.shape)
# Out:
# (300000, 60)

# %% [markdown]
# ## Check if all Categorical columns are matching in Train and Test Files

# %%
(np.sort(train['cat9'].unique()) == np.sort(test['cat9'].unique()))
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
for col in categorical_cols:
    print( (np.sort(train[col].unique()) == np.sort(test[col].unique())).all() )
# Out:
# True
# True
# True
# True
# True
# True
# True
# True
# True
# True

# %% [markdown]
# ## OneHotEncode Categorical Columns using Scikit Learn

# %%
ohe = OneHotEncoder(drop = 'first', sparse=False)

oh_cat_cols_train = pd.DataFrame(ohe.fit_transform(X_train[categorical_cols]))
oh_cat_cols_train.index = X_train.index
num_X_train = X_train.drop(categorical_cols, axis=1)
OH_X_train = pd.concat([num_X_train, oh_cat_cols_train], axis=1)

oh_cat_cols_val = pd.DataFrame(ohe.transform(X_valid[categorical_cols]))
oh_cat_cols_val.index = X_valid.index
num_X_val = X_valid.drop(categorical_cols, axis=1)
OH_X_val = pd.concat([num_X_val, oh_cat_cols_val], axis=1)

oh_cat_cols_test = pd.DataFrame(ohe.transform(test[categorical_cols]))
oh_cat_cols_test.index = test.index
num_X_test = test.drop(categorical_cols, axis=1)
OH_X_test = pd.concat([num_X_test, oh_cat_cols_test], axis=1)

# %%
print('X_train OHE {}'.format(OH_X_train.shape))
print('X_valid OHE {}'.format(OH_X_val.shape))
print('X_test OHE {}'.format(OH_X_test.shape))
# Out:
# X_train OHE (240000, 60)
# X_valid OHE (60000, 60)
# X_test OHE (200000, 60)

# %% [markdown]
# ## OneHotEncode Categorical Columns using Pandas Dummies

# %%
X_train_dum = pd.get_dummies(X_train, drop_first=True)
X_valid_dum = pd.get_dummies(X_valid, drop_first=True)
X_test_dum = pd.get_dummies(test, drop_first=True)

X_train_dum, X_valid_dum = X_train_dum.align(X_valid_dum, join='left', axis=1)
X_train_dum, X_test_dum = X_train_dum.align(X_test_dum, join='left', axis=1)

# %%
print('X_train Hot Encode Pandas {}'.format(X_train_dum.shape))
print('X_valid Hot Encode Pandas {}'.format(X_valid_dum.shape))
print('X_test Hot Encode Pandas {}'.format(X_test_dum.shape))
# Out:
# X_train Hot Encode Pandas (240000, 60)
# X_valid Hot Encode Pandas (60000, 60)
# X_test Hot Encode Pandas (200000, 60)

# %% [markdown]
# ## 1. Decision Tree with Ordinal Encoding

# %%
## Ordinal Encoding
y1 = tr['target']
X1 = tr.drop('target', axis = 'columns')
X_train1, X_valid1, y_train1, y_valid1 = train_test_split(X1, y1, test_size=0.2, random_state=0)

ordinal_encoder = OrdinalEncoder()
X_train1[categorical_cols] = ordinal_encoder.fit_transform(X_train1[categorical_cols])
X_valid1[categorical_cols] = ordinal_encoder.transform(X_valid1[categorical_cols])
# Out:
# C:\Users\AmirSaeed\.conda\envs\amir-gpu\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\AmirSaeed\.conda\envs\amir-gpu\lib\site-packages\pandas\core\indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())
# C:\Users\AmirSaeed\.conda\envs\amir-gpu\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\AmirSaeed\.conda\envs\amir-gpu\lib\site-packages\pandas\core\indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train1, y_train1)
dt_pred = dt_model.predict(X_valid1)
dt_mse = mean_squared_error(y_valid1, dt_pred, squared=False)
dt_mae = mean_absolute_error(y_valid1, dt_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(dt_mse, dt_mae))
# Out:
# Root Mean Squared Error 1.0622367622628097
# Mean Absolute Error 0.8406284951997104

# %% [markdown]
# ## 2. Decision Tree with OneHot Encoding (Sklean)

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(OH_X_train, y_train)
dt_pred = dt_model.predict(OH_X_val)
dt_mse = mean_squared_error(y_valid, dt_pred, squared=False)
dt_mae = mean_absolute_error(y_valid, dt_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(dt_mse, dt_mae))
# Out:
# Root Mean Squared Error 1.059524553186826
# Mean Absolute Error 0.8381901174891734

# %% [markdown]
# ## 3. Decision Tree with OneHot Encoding (Pandas)

# %%
dt_model = DecisionTreeRegressor()
dt_model.fit(X_train_dum, y_train)
dt_pred = dt_model.predict(X_valid_dum)
dt_mse = mean_squared_error(y_valid, dt_pred, squared=False)
dt_mae = mean_absolute_error(y_valid, dt_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(dt_mse, dt_mae))
# Out:
# Root Mean Squared Error 1.0569472471458274
# Mean Absolute Error 0.8361762911653638

# %% [markdown]
# ## 4. RandomForest with OneHot Encoding

# %%
rf_model = RandomForestRegressor(random_state=1)
rf_model.fit(OH_X_train, y_train)
rf_pred = rf_model.predict(OH_X_val)
rf_mse = mean_squared_error(y_valid, rf_pred, squared = False)
rf_mae = mean_absolute_error(y_valid, rf_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(rf_mse, rf_mae))
# Out:
# Root Mean Squared Error 0.7371244199109364
# Mean Absolute Error 0.584682034507699

# %% [markdown]
# ## 5. XGBoost with OneHot Encoding

# %%
xg_model = XGBRegressor(n_estimators = 500, n_jobs = -1)
xg_model.fit(OH_X_train, y_train)
xg_pred = xg_model.predict(OH_X_val)
xg_mse = mean_squared_error(y_valid, xg_pred, squared = False)
xg_mae = mean_absolute_error(y_valid, xg_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(xg_mse, xg_mae))
# Out:
# Root Mean Squared Error 0.7346368612780398
# Mean Absolute Error 0.5838970737118078

# %% [markdown]
# ## 6. XGBoost with OneHot Encoding (Optimized - A)

# %%
xg_model = XGBRegressor(n_estimators = 1000, learning_rate=0.05, n_jobs = -1)
xg_model.fit(OH_X_train, y_train)
xg_pred = xg_model.predict(OH_X_val)
xg_mse = mean_squared_error(y_valid, xg_pred, squared = False)
xg_mae = mean_absolute_error(y_valid, xg_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(xg_mse, xg_mae))
# Out:
# Root Mean Squared Error 0.7224471520010992
# Mean Absolute Error 0.574430716823482

# %% [markdown]
# ## 7. XGBoost Multiple Runs

# %%
def xgb_boost_reg(est, lr, x_train, y_train, x_valid, y_valid):
    xg_model = XGBRegressor(n_estimators = est, learning_rate=lr, n_jobs = -1, random_state=0)
    xg_model.fit(x_train, y_train)
    xg_pred = xg_model.predict(x_valid)
    xg_mse = mean_squared_error(y_valid, xg_pred, squared = False)
    xg_mae = mean_absolute_error(y_valid, xg_pred)
    #print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(xg_mse, xg_mae))
    return xg_mse, xg_mae

# %%
# mse , mae = xgb_boost_reg(est = 1000, lr = 0.05, x_train = OH_X_train, y_train = y_train, x_valid = OH_X_val, y_valid = y_valid)
# print(mse, mae)

# %%
n_est = [750, 1000, 1250]
lr = [0.04, 0.05, 0.06, 0.07, 0.08]
lr.sort()
results_mae = pd.DataFrame(index=n_est, columns=lr)
results_mse = pd.DataFrame(index=n_est, columns=lr)
results_mae
# Out:
#      0.04 0.05 0.06 0.07 0.08
# 750   NaN  NaN  NaN  NaN  NaN
# 1000  NaN  NaN  NaN  NaN  NaN
# 1250  NaN  NaN  NaN  NaN  NaN

# %%
for i,c in enumerate(results_mae):
    #print(i, c)
    for r in range(len(results_mae)):
        #print(n_est[r])
        mse , mae = xgb_boost_reg(est = n_est[r], lr = c, x_train = OH_X_train, y_train = y_train, x_valid = OH_X_val, y_valid = y_valid)
        results_mse.iloc[r, i] = mse
        results_mae.iloc[r, i] = mae

# %%
results_mse

# %%
results_mse.min()

# %%
results_mse.min().min()
# Out:
# 0.722139979052513

# %% [markdown]
# ## 8. XGBoost Multiple Runs (Optimized XGB Parameters)

# %%
params = {'learning_rate': 0.07853392035787837, 'reg_lambda': 1.7549293092194938e-05, 
          'reg_alpha': 14.68267919457715, 'subsample': 0.8031450486786944, 
          'colsample_bytree': 0.170759104940733, 'max_depth': 3}
xg_model = XGBRegressor(n_estimators = 5000, n_jobs = -1, random_state = 0, **params)
xg_model.fit(OH_X_train, y_train, early_stopping_rounds=300, eval_set=[(OH_X_val, y_valid)], verbose=1000)
xg_pred = xg_model.predict(OH_X_val)
xg_mse = mean_squared_error(y_valid, xg_pred, squared = False)
xg_mae = mean_absolute_error(y_valid, xg_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(xg_mse, xg_mae))
# Out:
# [0]	validation_0-rmse:7.16997
# [1000]	validation_0-rmse:0.72059
# [2000]	validation_0-rmse:0.71879
# [3000]	validation_0-rmse:0.71863
# [3207]	validation_0-rmse:0.71867
# Root Mean Squared Error 0.7186118486288169
# Mean Absolute Error 0.5718444099106272

# %% [markdown]
# ## 9. Default Model Performance from pycaret

# %%
from pycaret.regression import *

# %%
train = tr.drop('id', axis = 'columns')
X2 = pd.get_dummies(train, drop_first=True)
print(X2.shape)
# Out:
# (300000, 61)

# %%
# Provididing Clean Data to setup
s = setup(X2, target = 'target', session_id = 123)
# Out:
# <style  type="text/css" >
# #T_f59f0_row42_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_f59f0_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f59f0_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f59f0_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_f59f0_row0_col1" class="data row0 col1" >123</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_f59f0_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_f59f0_row1_col1" class="data row1 col1" >target</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_f59f0_row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_f59f0_row2_col1" class="data row2 col1" >(300000, 61)</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_f59f0_row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_f59f0_row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_f59f0_row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_f59f0_row4_col1" class="data row4 col1" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_f59f0_row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_f59f0_row5_col1" class="data row5 col1" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_f59f0_row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_f59f0_row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_f59f0_row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_f59f0_row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_f59f0_row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_f59f0_row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_f59f0_row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_f59f0_row9_col1" class="data row9 col1" >(209999, 60)</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_f59f0_row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_f59f0_row10_col1" class="data row10 col1" >(90001, 60)</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_f59f0_row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_f59f0_row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_f59f0_row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_f59f0_row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_f59f0_row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_f59f0_row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_f59f0_row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_f59f0_row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_f59f0_row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_f59f0_row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_f59f0_row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_f59f0_row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_f59f0_row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_f59f0_row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_f59f0_row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_f59f0_row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_f59f0_row19_col0" class="data row19 col0" >USI</td>
#                         <td id="T_f59f0_row19_col1" class="data row19 col1" >f8a9</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_f59f0_row20_col0" class="data row20 col0" >Imputation Type</td>
#                         <td id="T_f59f0_row20_col1" class="data row20 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_f59f0_row21_col0" class="data row21 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_f59f0_row21_col1" class="data row21 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_f59f0_row22_col0" class="data row22 col0" >Numeric Imputer</td>
#                         <td id="T_f59f0_row22_col1" class="data row22 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_f59f0_row23_col0" class="data row23 col0" >Iterative Imputation Numeric Model</td>
#                         <td id="T_f59f0_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_f59f0_level0_row24" class="row_heading level

# %%
best = compare_models()
# Out:
# <style  type="text/css" >
#     #T_4ae06_ th {
#           text-align: left;
#     }#T_4ae06_row0_col0,#T_4ae06_row0_col1,#T_4ae06_row0_col2,#T_4ae06_row0_col3,#T_4ae06_row0_col5,#T_4ae06_row0_col6,#T_4ae06_row1_col0,#T_4ae06_row1_col1,#T_4ae06_row1_col2,#T_4ae06_row1_col3,#T_4ae06_row1_col4,#T_4ae06_row1_col5,#T_4ae06_row1_col6,#T_4ae06_row2_col0,#T_4ae06_row2_col1,#T_4ae06_row2_col2,#T_4ae06_row2_col3,#T_4ae06_row2_col4,#T_4ae06_row2_col5,#T_4ae06_row2_col6,#T_4ae06_row3_col0,#T_4ae06_row3_col1,#T_4ae06_row3_col2,#T_4ae06_row3_col3,#T_4ae06_row3_col4,#T_4ae06_row3_col5,#T_4ae06_row3_col6,#T_4ae06_row4_col0,#T_4ae06_row4_col1,#T_4ae06_row4_col2,#T_4ae06_row4_col3,#T_4ae06_row4_col4,#T_4ae06_row4_col5,#T_4ae06_row4_col6,#T_4ae06_row5_col0,#T_4ae06_row5_col1,#T_4ae06_row5_col2,#T_4ae06_row5_col3,#T_4ae06_row5_col4,#T_4ae06_row5_col5,#T_4ae06_row5_col6,#T_4ae06_row6_col0,#T_4ae06_row6_col1,#T_4ae06_row6_col2,#T_4ae06_row6_col3,#T_4ae06_row6_col4,#T_4ae06_row6_col5,#T_4ae06_row6_col6,#T_4ae06_row7_col0,#T_4ae06_row7_col1,#T_4ae06_row7_col2,#T_4ae06_row7_col3,#T_4ae06_row7_col4,#T_4ae06_row7_col5,#T_4ae06_row7_col6,#T_4ae06_row8_col0,#T_4ae06_row8_col1,#T_4ae06_row8_col2,#T_4ae06_row8_col3,#T_4ae06_row8_col4,#T_4ae06_row8_col5,#T_4ae06_row8_col6,#T_4ae06_row9_col0,#T_4ae06_row9_col1,#T_4ae06_row9_col2,#T_4ae06_row9_col3,#T_4ae06_row9_col4,#T_4ae06_row9_col5,#T_4ae06_row9_col6,#T_4ae06_row10_col0,#T_4ae06_row10_col1,#T_4ae06_row10_col2,#T_4ae06_row10_col3,#T_4ae06_row10_col4,#T_4ae06_row10_col5,#T_4ae06_row10_col6,#T_4ae06_row11_col0,#T_4ae06_row11_col4,#T_4ae06_row12_col0,#T_4ae06_row12_col1,#T_4ae06_row12_col2,#T_4ae06_row12_col3,#T_4ae06_row12_col4,#T_4ae06_row12_col5,#T_4ae06_row12_col6,#T_4ae06_row13_col0,#T_4ae06_row13_col1,#T_4ae06_row13_col2,#T_4ae06_row13_col3,#T_4ae06_row13_col4,#T_4ae06_row13_col5,#T_4ae06_row13_col6,#T_4ae06_row14_col0,#T_4ae06_row14_col1,#T_4ae06_row14_col2,#T_4ae06_row14_col3,#T_4ae06_row14_col4,#T_4ae06_row14_col5,#T_4ae06_row14_col6,#T_4ae06_row15_col0,#T_4ae06_row15_col1,#T_4ae06_row15_col2,#T_4ae06_row15_col3,#T_4ae06_row15_col4,#T_4ae06_row15_col5,#T_4ae06_row15_col6,#T_4ae06_row16_col0,#T_4ae06_row16_col1,#T_4ae06_row16_col2,#T_4ae06_row16_col3,#T_4ae06_row16_col4,#T_4ae06_row16_col5,#T_4ae06_row16_col6,#T_4ae06_row17_col0,#T_4ae06_row17_col1,#T_4ae06_row17_col2,#T_4ae06_row17_col3,#T_4ae06_row17_col4,#T_4ae06_row17_col5,#T_4ae06_row17_col6,#T_4ae06_row18_col0,#T_4ae06_row18_col1,#T_4ae06_row18_col2,#T_4ae06_row18_col3,#T_4ae06_row18_col4,#T_4ae06_row18_col5,#T_4ae06_row18_col6{
#             text-align:  left;
#             text-align:  left;
#         }#T_4ae06_row0_col4,#T_4ae06_row11_col1,#T_4ae06_row11_col2,#T_4ae06_row11_col3,#T_4ae06_row11_col5,#T_4ae06_row11_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_4ae06_row0_col7,#T_4ae06_row1_col7,#T_4ae06_row2_col7,#T_4ae06_row3_col7,#T_4ae06_row4_col7,#T_4ae06_row5_col7,#T_4ae06_row6_col7,#T_4ae06_row7_col7,#T_4ae06_row8_col7,#T_4ae06_row9_col7,#T_4ae06_row10_col7,#T_4ae06_row11_col7,#T_4ae06_row12_col7,#T_4ae06_row14_col7,#T_4ae06_row15_col7,#T_4ae06_row16_col7,#T_4ae06_row17_col7,#T_4ae06_row18_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_4ae06_row13_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_4ae06_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>        <th class="col_heading level0 col7" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4ae06_level0_row0" class="row_heading level0 row0" >catboost</th>
#                         <td id="T_4ae06_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#                         <td id="T_4ae06_row0_col1" class="data row0 col1" >0.5733</td>
#                         <td id="T_4ae06_row0_col2" class="data row0 col2" >0.5199</td>
#                         <td id="T_4ae06_row0_col3" class="data row0 col3" >0.7210</td>
#                         <td id="T_4ae06_row0_col4" class="data row0 col4" >0.0653</td>
#                         <td id="T_4ae06_row0_col5" class="data row0 col5" >0.0784</td>
#                         <td id="T_4ae06_row0_col6" class="data row0 col6" >0.0705</td>
#                         <td id="T_4ae06_row0_col7" class="data row0 col7" >20.9300</td>
#             </tr>
#             <tr>
#                         <th id="T_4ae06_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#                         <td id="T_4ae06_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_4ae06_row1_col1" class="data row1 col1" >0.5757</td>
#                         <td id="T_4ae06_row1_col2" class="data row1 col2" >0.5255</td>
#                         <td id="T_4ae06_row1_col3" class="data row1 col3" >0.7249</td>
#                         <td id="T_4ae06_row1_col4" class="data row1 col4" >0.0553</td>
#                         <td id="T_4ae06_row1_col5" class="data row1 col5" >0.0789</td>
#                         <td id="T_4ae06_row1_col6" class="data row1 col6" >0.0708</td>
#                         <td id="T_4ae06_row1_col7" class="data row1 col7" >1.9060</td>
#             </tr>
#             <tr>
#                         <th id="T_4ae06_level0_row2" class="row_heading level0 row2" >xgboost</th>
#                         <td id="T_4ae06_row2_col0" class="data row2 col0" >Extreme Gradient Boosting</td>
#                         <td id="T_4ae06_row2_col1" class="data row2 col1" >0.5767</td>
#                         <td id="T_4ae06_row2_col2" class="data row2 col2" >0.5261</td>
#                         <td id="T_4ae06_row2_col3" class="data row2 col3" >0.7253</td>
#                         <td id="T_4ae06_row2_col4" class="data row2 col4" >0.0541</td>
#                         <td id="T_4ae06_row2_col5" class="data row2 col5" >0.0789</td>
#                         <td id="T_4ae06_row2_col6" class="data row2 col6" >0.0709</td>
#                         <td id="T_4ae06_row2_col7" class="data row2 col7" >30.9830</td>
#             </tr>
#             <tr>
#                         <th id="T_4ae06_level0_row3" class="row_heading level0 row3" >gbr</th>
#                         <td id="T_4ae06_row3_col0" class="data row3 col0" >Gradient Boosting Regressor</td>
#                         <td id="T_4ae06_row3_col1" class="data row3 col1" >0.5799</td>
#                         <td id="T_4ae06_row3_col2" class="data row3 col2" >0.5337</td>
#                         <td id="T_4ae06_row3_col3" class="data row3 col3" >0.7306</td>
#                         <td id="T_4ae06_row3_col4" class="data row3 col4" >0.0405</td>
#                         <td id="T_4ae06_row3_col5" class="data row3 col5" >0.0795</td>
#                         <td id="T_4ae06_row3_col6" class="data row3 col6" >0.0714</td>
#                         <td id="T_4ae06_row3_col7" class="data row3 col7" >42.5080</td>
#             </tr>
#             <tr>
#                         <th id="T_4ae06_level0_row4" class="row_heading level0 row4" >rf</th>
#                         <td id="T_4ae06_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#                         <td id="T_4ae06_row4_col1" class="data row4 col1" >0.5836</td>
#                         <td id="T_4ae06_row4_col2" class="data row4 col2" >0.5404</td>
#                         <td id="T_4ae06_row4_col3" class="data row4 col3" >0.7351</td>
#                         <td id="T_4ae06_row4_col4" class="data row4 col4" >0.0286</td>

# %%
model = create_model('lightgbm')
# Out:
# <style  type="text/css" >
# #T_c288c_row10_col0,#T_c288c_row10_col1,#T_c288c_row10_col2,#T_c288c_row10_col3,#T_c288c_row10_col4,#T_c288c_row10_col5{
#             background:  yellow;
#         }</style><table id="T_c288c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c288c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c288c_row0_col0" class="data row0 col0" >0.5772</td>
#                         <td id="T_c288c_row0_col1" class="data row0 col1" >0.5246</td>
#                         <td id="T_c288c_row0_col2" class="data row0 col2" >0.7243</td>
#                         <td id="T_c288c_row0_col3" class="data row0 col3" >0.0566</td>
#                         <td id="T_c288c_row0_col4" class="data row0 col4" >0.0784</td>
#                         <td id="T_c288c_row0_col5" class="data row0 col5" >0.0705</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c288c_row1_col0" class="data row1 col0" >0.5717</td>
#                         <td id="T_c288c_row1_col1" class="data row1 col1" >0.5147</td>
#                         <td id="T_c288c_row1_col2" class="data row1 col2" >0.7174</td>
#                         <td id="T_c288c_row1_col3" class="data row1 col3" >0.0535</td>
#                         <td id="T_c288c_row1_col4" class="data row1 col4" >0.0774</td>
#                         <td id="T_c288c_row1_col5" class="data row1 col5" >0.0697</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c288c_row2_col0" class="data row2 col0" >0.5796</td>
#                         <td id="T_c288c_row2_col1" class="data row2 col1" >0.5295</td>
#                         <td id="T_c288c_row2_col2" class="data row2 col2" >0.7276</td>
#                         <td id="T_c288c_row2_col3" class="data row2 col3" >0.0539</td>
#                         <td id="T_c288c_row2_col4" class="data row2 col4" >0.0789</td>
#                         <td id="T_c288c_row2_col5" class="data row2 col5" >0.0709</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c288c_row3_col0" class="data row3 col0" >0.5777</td>
#                         <td id="T_c288c_row3_col1" class="data row3 col1" >0.5309</td>
#                         <td id="T_c288c_row3_col2" class="data row3 col2" >0.7286</td>
#                         <td id="T_c288c_row3_col3" class="data row3 col3" >0.0502</td>
#                         <td id="T_c288c_row3_col4" class="data row3 col4" >0.0796</td>
#                         <td id="T_c288c_row3_col5" class="data row3 col5" >0.0709</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c288c_row4_col0" class="data row4 col0" >0.5797</td>
#                         <td id="T_c288c_row4_col1" class="data row4 col1" >0.5343</td>
#                         <td id="T_c288c_row4_col2" class="data row4 col2" >0.7310</td>
#                         <td id="T_c288c_row4_col3" class="data row4 col3" >0.0543</td>
#                         <td id="T_c288c_row4_col4" class="data row4 col4" >0.0797</td>
#                         <td id="T_c288c_row4_col5" class="data row4 col5" >0.0712</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c288c_row5_col0" class="data row5 col0" >0.5753</td>
#                         <td id="T_c288c_row5_col1" class="data row5 col1" >0.5261</td>
#                         <td id="T_c288c_row5_col2" class="data row5 col2" >0.7253</td>
#                         <td id="T_c288c_row5_col3" class="data row5 col3" >0.0545</td>
#                         <td id="T_c288c_row5_col4" class="data row5 col4" >0.0786</td>
#                         <td id="T_c288c_row5_col5" class="data row5 col5" >0.0704</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c288c_row6_col0" class="data row6 col0" >0.5744</td>
#                         <td id="T_c288c_row6_col1" class="data row6 col1" >0.5231</td>
#                         <td id="T_c288c_row6_col2" class="data row6 col2" >0.7233</td>
#                         <td id="T_c288c_row6_col3" class="data row6 col3" >0.0595</td>
#                         <td id="T_c288c_row6_col4" class="data row6 col4" >0.0788</td>
#                         <td id="T_c288c_row6_col5" class="data row6 col5" >0.0706</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c288c_row7_col0" class="data row7 col0" >0.5736</td>
#                         <td id="T_c288c_row7_col1" class="data row7 col1" >0.5258</td>
#                         <td id="T_c288c_row7_col2" class="data row7 col2" >0.7251</td>
#                         <td id="T_c288c_row7_col3" class="data row7 col3" >0.0571</td>
#                         <td id="T_c288c_row7_col4" class="data row7 col4" >0.0798</td>
#                         <td id="T_c288c_row7_col5" class="data row7 col5" >0.0729</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c288c_row8_col0" class="data row8 col0" >0.5755</td>
#                         <td id="T_c288c_row8_col1" class="data row8 col1" >0.5259</td>
#                         <td id="T_c288c_row8_col2" class="data row8 col2" >0.7252</td>
#                         <td id="T_c288c_row8_col3" class="data row8 col3" >0.0588</td>
#                         <td id="T_c288c_row8_col4" class="data row8 col4" >0.0792</td>
#                         <td id="T_c288c_row8_col5" class="data row8 col5" >0.0709</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_c288c_row9_col0" class="data row9 col0" >0.5724</td>
#                         <td id="T_c288c_row9_col1" class="data row9 col1" >0.5198</td>
#                         <td id="T_c288c_row9_col2" class="data row9 col2" >0.7210</td>
#                         <td id="T_c288c_row9_col3" class="data row9 col3" >0.0549</td>
#                         <td id="T_c288c_row9_col4" class="data row9 col4" >0.0784</td>
#                         <td id="T_c288c_row9_col5" class="data row9 col5" >0.0703</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_c288c_row10_col0" class="data row10 col0" >0.5757</td>
#                         <td id="T_c288c_row10_col1" class="data row10 col1" >0.5255</td>
#                         <td id="T_c288c_row10_col2" class="data row10 col2" >0.7249</td>
#                         <td id="T_c288c_row10_col3" class="data row10 col3" >0.0553</td>
#                         <td id="T_c288c_row10_col4" class="data row10 col4" >0.0789</td>
#                         <td id="T_c288c_row10_col5" class="data row10 col5" >0.0708</td>
#             </tr>
#             <tr>
#                         <th id="T_c288c_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_c288c_row11_col0" class="data row11 col0" >0.0027</td>

# %%
print(model)
# Out:
# LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               importance_type='split', learning_rate=0.1, max_depth=-1,
#               min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#               n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#               random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#               subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
lg_model = LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
              importance_type='split', learning_rate=0.1, max_depth=-1,
              min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
              n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
              random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent=True,
              subsample=1.0, subsample_for_bin=200000, subsample_freq=0)
lg_model.fit(OH_X_train, y_train)
lg_pred = lg_model.predict(OH_X_val)
lg_mse = mean_squared_error(y_valid, lg_pred, squared = False)
lg_mae = mean_absolute_error(y_valid, lg_pred)
print('Root Mean Squared Error {}\nMean Absolute Error {}'.format(lg_mse, lg_mae))
# Out:
# Root Mean Squared Error 0.7259878625204318
# Mean Absolute Error 0.5759559951762175

# %% [markdown]
# ## 10. Optimized Model from pycaret

# %%
tuned_model_1 = tune_model(model, search_library = 'optuna')
# Out:
# <style  type="text/css" >
# #T_86e2b_row10_col0,#T_86e2b_row10_col1,#T_86e2b_row10_col2,#T_86e2b_row10_col3,#T_86e2b_row10_col4,#T_86e2b_row10_col5{
#             background:  yellow;
#         }</style><table id="T_86e2b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86e2b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_86e2b_row0_col0" class="data row0 col0" >0.5771</td>
#                         <td id="T_86e2b_row0_col1" class="data row0 col1" >0.5237</td>
#                         <td id="T_86e2b_row0_col2" class="data row0 col2" >0.7237</td>
#                         <td id="T_86e2b_row0_col3" class="data row0 col3" >0.0582</td>
#                         <td id="T_86e2b_row0_col4" class="data row0 col4" >0.0783</td>
#                         <td id="T_86e2b_row0_col5" class="data row0 col5" >0.0705</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_86e2b_row1_col0" class="data row1 col0" >0.5732</td>
#                         <td id="T_86e2b_row1_col1" class="data row1 col1" >0.5161</td>
#                         <td id="T_86e2b_row1_col2" class="data row1 col2" >0.7184</td>
#                         <td id="T_86e2b_row1_col3" class="data row1 col3" >0.0508</td>
#                         <td id="T_86e2b_row1_col4" class="data row1 col4" >0.0775</td>
#                         <td id="T_86e2b_row1_col5" class="data row1 col5" >0.0699</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_86e2b_row2_col0" class="data row2 col0" >0.5803</td>
#                         <td id="T_86e2b_row2_col1" class="data row2 col1" >0.5306</td>
#                         <td id="T_86e2b_row2_col2" class="data row2 col2" >0.7284</td>
#                         <td id="T_86e2b_row2_col3" class="data row2 col3" >0.0519</td>
#                         <td id="T_86e2b_row2_col4" class="data row2 col4" >0.0790</td>
#                         <td id="T_86e2b_row2_col5" class="data row2 col5" >0.0710</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_86e2b_row3_col0" class="data row3 col0" >0.5777</td>
#                         <td id="T_86e2b_row3_col1" class="data row3 col1" >0.5304</td>
#                         <td id="T_86e2b_row3_col2" class="data row3 col2" >0.7283</td>
#                         <td id="T_86e2b_row3_col3" class="data row3 col3" >0.0511</td>
#                         <td id="T_86e2b_row3_col4" class="data row3 col4" >0.0795</td>
#                         <td id="T_86e2b_row3_col5" class="data row3 col5" >0.0709</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_86e2b_row4_col0" class="data row4 col0" >0.5806</td>
#                         <td id="T_86e2b_row4_col1" class="data row4 col1" >0.5348</td>
#                         <td id="T_86e2b_row4_col2" class="data row4 col2" >0.7313</td>
#                         <td id="T_86e2b_row4_col3" class="data row4 col3" >0.0534</td>
#                         <td id="T_86e2b_row4_col4" class="data row4 col4" >0.0797</td>
#                         <td id="T_86e2b_row4_col5" class="data row4 col5" >0.0713</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_86e2b_row5_col0" class="data row5 col0" >0.5747</td>
#                         <td id="T_86e2b_row5_col1" class="data row5 col1" >0.5240</td>
#                         <td id="T_86e2b_row5_col2" class="data row5 col2" >0.7239</td>
#                         <td id="T_86e2b_row5_col3" class="data row5 col3" >0.0582</td>
#                         <td id="T_86e2b_row5_col4" class="data row5 col4" >0.0784</td>
#                         <td id="T_86e2b_row5_col5" class="data row5 col5" >0.0703</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_86e2b_row6_col0" class="data row6 col0" >0.5742</td>
#                         <td id="T_86e2b_row6_col1" class="data row6 col1" >0.5217</td>
#                         <td id="T_86e2b_row6_col2" class="data row6 col2" >0.7223</td>
#                         <td id="T_86e2b_row6_col3" class="data row6 col3" >0.0621</td>
#                         <td id="T_86e2b_row6_col4" class="data row6 col4" >0.0787</td>
#                         <td id="T_86e2b_row6_col5" class="data row6 col5" >0.0705</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_86e2b_row7_col0" class="data row7 col0" >0.5738</td>
#                         <td id="T_86e2b_row7_col1" class="data row7 col1" >0.5242</td>
#                         <td id="T_86e2b_row7_col2" class="data row7 col2" >0.7240</td>
#                         <td id="T_86e2b_row7_col3" class="data row7 col3" >0.0599</td>
#                         <td id="T_86e2b_row7_col4" class="data row7 col4" >0.0797</td>
#                         <td id="T_86e2b_row7_col5" class="data row7 col5" >0.0729</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_86e2b_row8_col0" class="data row8 col0" >0.5756</td>
#                         <td id="T_86e2b_row8_col1" class="data row8 col1" >0.5246</td>
#                         <td id="T_86e2b_row8_col2" class="data row8 col2" >0.7243</td>
#                         <td id="T_86e2b_row8_col3" class="data row8 col3" >0.0612</td>
#                         <td id="T_86e2b_row8_col4" class="data row8 col4" >0.0790</td>
#                         <td id="T_86e2b_row8_col5" class="data row8 col5" >0.0709</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_86e2b_row9_col0" class="data row9 col0" >0.5720</td>
#                         <td id="T_86e2b_row9_col1" class="data row9 col1" >0.5197</td>
#                         <td id="T_86e2b_row9_col2" class="data row9 col2" >0.7209</td>
#                         <td id="T_86e2b_row9_col3" class="data row9 col3" >0.0551</td>
#                         <td id="T_86e2b_row9_col4" class="data row9 col4" >0.0784</td>
#                         <td id="T_86e2b_row9_col5" class="data row9 col5" >0.0702</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_86e2b_row10_col0" class="data row10 col0" >0.5759</td>
#                         <td id="T_86e2b_row10_col1" class="data row10 col1" >0.5250</td>
#                         <td id="T_86e2b_row10_col2" class="data row10 col2" >0.7246</td>
#                         <td id="T_86e2b_row10_col3" class="data row10 col3" >0.0562</td>
#                         <td id="T_86e2b_row10_col4" class="data row10 col4" >0.0788</td>
#                         <td id="T_86e2b_row10_col5" class="data row10 col5" >0.0708</td>
#             </tr>
#             <tr>
#                         <th id="T_86e2b_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_86e2b_row11_col0" class="data row11 col0" >0.0028</td>

# %%
print(tuned_model_1)
# Out:
# LGBMRegressor(bagging_fraction=0.43679733794174347, bagging_freq=4,
#               boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#               feature_fraction=0.9001841001160923, importance_type='split',
#               learning_rate=0.05439296712851782, max_depth=-1,
#               min_child_samples=81, min_child_weight=0.001,
#               min_split_gain=0.7394984245515656, n_estimators=264, n_jobs=-1,
#               num_leaves=109, objective=None, random_state=123,
#               reg_alpha=0.1587450786338632, reg_lambda=8.859254362320617e-10,
#               silent=True, subsample=1.0, subsample_for_bin=200000,
#               subsample_freq=0)

# %%
tuned_model_2 = tune_model(model, search_library = 'scikit-learn')
# Out:
# <style  type="text/css" >
# #T_20539_row10_col0,#T_20539_row10_col1,#T_20539_row10_col2,#T_20539_row10_col3,#T_20539_row10_col4,#T_20539_row10_col5{
#             background:  yellow;
#         }</style><table id="T_20539_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_20539_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_20539_row0_col0" class="data row0 col0" >0.5741</td>
#                         <td id="T_20539_row0_col1" class="data row0 col1" >0.5187</td>
#                         <td id="T_20539_row0_col2" class="data row0 col2" >0.7202</td>
#                         <td id="T_20539_row0_col3" class="data row0 col3" >0.0672</td>
#                         <td id="T_20539_row0_col4" class="data row0 col4" >0.0780</td>
#                         <td id="T_20539_row0_col5" class="data row0 col5" >0.0701</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_20539_row1_col0" class="data row1 col0" >0.5703</td>
#                         <td id="T_20539_row1_col1" class="data row1 col1" >0.5107</td>
#                         <td id="T_20539_row1_col2" class="data row1 col2" >0.7146</td>
#                         <td id="T_20539_row1_col3" class="data row1 col3" >0.0608</td>
#                         <td id="T_20539_row1_col4" class="data row1 col4" >0.0771</td>
#                         <td id="T_20539_row1_col5" class="data row1 col5" >0.0695</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_20539_row2_col0" class="data row2 col0" >0.5785</td>
#                         <td id="T_20539_row2_col1" class="data row2 col1" >0.5262</td>
#                         <td id="T_20539_row2_col2" class="data row2 col2" >0.7254</td>
#                         <td id="T_20539_row2_col3" class="data row2 col3" >0.0598</td>
#                         <td id="T_20539_row2_col4" class="data row2 col4" >0.0786</td>
#                         <td id="T_20539_row2_col5" class="data row2 col5" >0.0707</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_20539_row3_col0" class="data row3 col0" >0.5758</td>
#                         <td id="T_20539_row3_col1" class="data row3 col1" >0.5250</td>
#                         <td id="T_20539_row3_col2" class="data row3 col2" >0.7245</td>
#                         <td id="T_20539_row3_col3" class="data row3 col3" >0.0608</td>
#                         <td id="T_20539_row3_col4" class="data row3 col4" >0.0791</td>
#                         <td id="T_20539_row3_col5" class="data row3 col5" >0.0707</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_20539_row4_col0" class="data row4 col0" >0.5792</td>
#                         <td id="T_20539_row4_col1" class="data row4 col1" >0.5295</td>
#                         <td id="T_20539_row4_col2" class="data row4 col2" >0.7276</td>
#                         <td id="T_20539_row4_col3" class="data row4 col3" >0.0628</td>
#                         <td id="T_20539_row4_col4" class="data row4 col4" >0.0793</td>
#                         <td id="T_20539_row4_col5" class="data row4 col5" >0.0711</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_20539_row5_col0" class="data row5 col0" >0.5742</td>
#                         <td id="T_20539_row5_col1" class="data row5 col1" >0.5218</td>
#                         <td id="T_20539_row5_col2" class="data row5 col2" >0.7224</td>
#                         <td id="T_20539_row5_col3" class="data row5 col3" >0.0622</td>
#                         <td id="T_20539_row5_col4" class="data row5 col4" >0.0782</td>
#                         <td id="T_20539_row5_col5" class="data row5 col5" >0.0702</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_20539_row6_col0" class="data row6 col0" >0.5726</td>
#                         <td id="T_20539_row6_col1" class="data row6 col1" >0.5184</td>
#                         <td id="T_20539_row6_col2" class="data row6 col2" >0.7200</td>
#                         <td id="T_20539_row6_col3" class="data row6 col3" >0.0681</td>
#                         <td id="T_20539_row6_col4" class="data row6 col4" >0.0784</td>
#                         <td id="T_20539_row6_col5" class="data row6 col5" >0.0703</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_20539_row7_col0" class="data row7 col0" >0.5714</td>
#                         <td id="T_20539_row7_col1" class="data row7 col1" >0.5206</td>
#                         <td id="T_20539_row7_col2" class="data row7 col2" >0.7216</td>
#                         <td id="T_20539_row7_col3" class="data row7 col3" >0.0663</td>
#                         <td id="T_20539_row7_col4" class="data row7 col4" >0.0794</td>
#                         <td id="T_20539_row7_col5" class="data row7 col5" >0.0726</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_20539_row8_col0" class="data row8 col0" >0.5734</td>
#                         <td id="T_20539_row8_col1" class="data row8 col1" >0.5205</td>
#                         <td id="T_20539_row8_col2" class="data row8 col2" >0.7214</td>
#                         <td id="T_20539_row8_col3" class="data row8 col3" >0.0685</td>
#                         <td id="T_20539_row8_col4" class="data row8 col4" >0.0787</td>
#                         <td id="T_20539_row8_col5" class="data row8 col5" >0.0706</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_20539_row9_col0" class="data row9 col0" >0.5708</td>
#                         <td id="T_20539_row9_col1" class="data row9 col1" >0.5155</td>
#                         <td id="T_20539_row9_col2" class="data row9 col2" >0.7180</td>
#                         <td id="T_20539_row9_col3" class="data row9 col3" >0.0628</td>
#                         <td id="T_20539_row9_col4" class="data row9 col4" >0.0781</td>
#                         <td id="T_20539_row9_col5" class="data row9 col5" >0.0700</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_20539_row10_col0" class="data row10 col0" >0.5740</td>
#                         <td id="T_20539_row10_col1" class="data row10 col1" >0.5207</td>
#                         <td id="T_20539_row10_col2" class="data row10 col2" >0.7216</td>
#                         <td id="T_20539_row10_col3" class="data row10 col3" >0.0639</td>
#                         <td id="T_20539_row10_col4" class="data row10 col4" >0.0785</td>
#                         <td id="T_20539_row10_col5" class="data row10 col5" >0.0706</td>
#             </tr>
#             <tr>
#                         <th id="T_20539_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_20539_row11_col0" class="data row11 col0" >0.0029</td>

# %%
tuned_model_3 = tune_model(model, search_library = 'scikit-optimize')
# Out:
# <style  type="text/css" >
# #T_0574a_row10_col0,#T_0574a_row10_col1,#T_0574a_row10_col2,#T_0574a_row10_col3,#T_0574a_row10_col4,#T_0574a_row10_col5{
#             background:  yellow;
#         }</style><table id="T_0574a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0574a_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0574a_row0_col0" class="data row0 col0" >0.5777</td>
#                         <td id="T_0574a_row0_col1" class="data row0 col1" >0.5265</td>
#                         <td id="T_0574a_row0_col2" class="data row0 col2" >0.7256</td>
#                         <td id="T_0574a_row0_col3" class="data row0 col3" >0.0533</td>
#                         <td id="T_0574a_row0_col4" class="data row0 col4" >0.0786</td>
#                         <td id="T_0574a_row0_col5" class="data row0 col5" >0.0706</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_0574a_row1_col0" class="data row1 col0" >0.5723</td>
#                         <td id="T_0574a_row1_col1" class="data row1 col1" >0.5163</td>
#                         <td id="T_0574a_row1_col2" class="data row1 col2" >0.7186</td>
#                         <td id="T_0574a_row1_col3" class="data row1 col3" >0.0504</td>
#                         <td id="T_0574a_row1_col4" class="data row1 col4" >0.0775</td>
#                         <td id="T_0574a_row1_col5" class="data row1 col5" >0.0698</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_0574a_row2_col0" class="data row2 col0" >0.5807</td>
#                         <td id="T_0574a_row2_col1" class="data row2 col1" >0.5317</td>
#                         <td id="T_0574a_row2_col2" class="data row2 col2" >0.7292</td>
#                         <td id="T_0574a_row2_col3" class="data row2 col3" >0.0499</td>
#                         <td id="T_0574a_row2_col4" class="data row2 col4" >0.0791</td>
#                         <td id="T_0574a_row2_col5" class="data row2 col5" >0.0710</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_0574a_row3_col0" class="data row3 col0" >0.5782</td>
#                         <td id="T_0574a_row3_col1" class="data row3 col1" >0.5320</td>
#                         <td id="T_0574a_row3_col2" class="data row3 col2" >0.7294</td>
#                         <td id="T_0574a_row3_col3" class="data row3 col3" >0.0483</td>
#                         <td id="T_0574a_row3_col4" class="data row3 col4" >0.0797</td>
#                         <td id="T_0574a_row3_col5" class="data row3 col5" >0.0710</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_0574a_row4_col0" class="data row4 col0" >0.5812</td>
#                         <td id="T_0574a_row4_col1" class="data row4 col1" >0.5362</td>
#                         <td id="T_0574a_row4_col2" class="data row4 col2" >0.7322</td>
#                         <td id="T_0574a_row4_col3" class="data row4 col3" >0.0510</td>
#                         <td id="T_0574a_row4_col4" class="data row4 col4" >0.0799</td>
#                         <td id="T_0574a_row4_col5" class="data row4 col5" >0.0714</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_0574a_row5_col0" class="data row5 col0" >0.5758</td>
#                         <td id="T_0574a_row5_col1" class="data row5 col1" >0.5278</td>
#                         <td id="T_0574a_row5_col2" class="data row5 col2" >0.7265</td>
#                         <td id="T_0574a_row5_col3" class="data row5 col3" >0.0515</td>
#                         <td id="T_0574a_row5_col4" class="data row5 col4" >0.0787</td>
#                         <td id="T_0574a_row5_col5" class="data row5 col5" >0.0705</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_0574a_row6_col0" class="data row6 col0" >0.5761</td>
#                         <td id="T_0574a_row6_col1" class="data row6 col1" >0.5262</td>
#                         <td id="T_0574a_row6_col2" class="data row6 col2" >0.7254</td>
#                         <td id="T_0574a_row6_col3" class="data row6 col3" >0.0541</td>
#                         <td id="T_0574a_row6_col4" class="data row6 col4" >0.0791</td>
#                         <td id="T_0574a_row6_col5" class="data row6 col5" >0.0708</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_0574a_row7_col0" class="data row7 col0" >0.5751</td>
#                         <td id="T_0574a_row7_col1" class="data row7 col1" >0.5282</td>
#                         <td id="T_0574a_row7_col2" class="data row7 col2" >0.7268</td>
#                         <td id="T_0574a_row7_col3" class="data row7 col3" >0.0526</td>
#                         <td id="T_0574a_row7_col4" class="data row7 col4" >0.0800</td>
#                         <td id="T_0574a_row7_col5" class="data row7 col5" >0.0732</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_0574a_row8_col0" class="data row8 col0" >0.5763</td>
#                         <td id="T_0574a_row8_col1" class="data row8 col1" >0.5283</td>
#                         <td id="T_0574a_row8_col2" class="data row8 col2" >0.7268</td>
#                         <td id="T_0574a_row8_col3" class="data row8 col3" >0.0546</td>
#                         <td id="T_0574a_row8_col4" class="data row8 col4" >0.0793</td>
#                         <td id="T_0574a_row8_col5" class="data row8 col5" >0.0710</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_0574a_row9_col0" class="data row9 col0" >0.5734</td>
#                         <td id="T_0574a_row9_col1" class="data row9 col1" >0.5220</td>
#                         <td id="T_0574a_row9_col2" class="data row9 col2" >0.7225</td>
#                         <td id="T_0574a_row9_col3" class="data row9 col3" >0.0510</td>
#                         <td id="T_0574a_row9_col4" class="data row9 col4" >0.0786</td>
#                         <td id="T_0574a_row9_col5" class="data row9 col5" >0.0704</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row10" class="row_heading level0 row10" >Mean</th>
#                         <td id="T_0574a_row10_col0" class="data row10 col0" >0.5767</td>
#                         <td id="T_0574a_row10_col1" class="data row10 col1" >0.5275</td>
#                         <td id="T_0574a_row10_col2" class="data row10 col2" >0.7263</td>
#                         <td id="T_0574a_row10_col3" class="data row10 col3" >0.0517</td>
#                         <td id="T_0574a_row10_col4" class="data row10 col4" >0.0790</td>
#                         <td id="T_0574a_row10_col5" class="data row10 col5" >0.0710</td>
#             </tr>
#             <tr>
#                         <th id="T_0574a_level0_row11" class="row_heading level0 row11" >SD</th>
#                         <td id="T_0574a_row11_col0" class="data row11 col0" >0.0027</td>
